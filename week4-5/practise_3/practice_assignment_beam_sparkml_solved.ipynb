# %% [markdown]
# # Practice Assignment
#
# # Apache Beam and Spark ML
#
# ---
#
# ## Learning Outcomes
#
# After completing this notebook students should be able to:
#
# 1. Create Apache Beam Pipelines
# 2. Work with PCollections
# 3. Apply PTransforms
# 4. Perform Aggregations
# 5. Build Custom DoFns
# 6. Understand Windowing Concepts
# 7. Create Spark DataFrames
# 8. Apply Feature Engineering
# 9. Build Spark ML Pipelines
# 10. Perform Model Tuning
#
# ---
#
# ### Instructions
#
# - Read the provided lecture material.
# - Attempt every TODO section first.
# - Use hints when required.
# - View solutions only after attempting the task.

# %% [markdown]
# # Exercise 1: Install Required Libraries
#
# ## Background
#
#
# Apache Beam is used for building data processing pipelines.
#
# PySpark is used for distributed data processing and
# machine learning workflows.
#
#
# ## Dataset / Input
#
#
# Required Libraries
#
# 1. apache-beam
# 2. pyspark
#
#
# ## Task
#
#
# Install the required libraries.
#
#
# ## Hint
#
#
# Use pip install.

# %%
# =====================================================
# TODO
# =====================================================


# Install required packages

# %% [markdown]
# ## Solution

# %%
# !pip install apache-beam
# !pip install pyspark

# %% [markdown]
# # Exercise 2: Import Libraries
#
# ## Background
#
#
# Most Beam programs require apache_beam.
#
# Most Spark ML workflows require SparkSession.
#
#
# ## Dataset / Input
#
#
# Libraries
#
# - apache_beam
# - SparkSession
#
#
# ## Task
#
#
# Import the required libraries.
#
#
# ## Hint
#
#
# Use import statements.

# %%
# =====================================================
# TODO
# =====================================================


# Import required libraries

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

from pyspark.sql import SparkSession

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# # Apache Beam
#
# In this section we will use realistic business datasets.
#
# Scenarios:
#
# - Product Catalog
# - Customer Orders
# - Website Clickstream
# - Inventory Tracking
#
# The goal is to learn Beam concepts while solving
# realistic data engineering problems.

# %% [markdown]
# # Exercise 3: Create Your First Pipeline
#
# ## Background
#
#
# An online store wants to process product names.
#
# The first step is to create a pipeline and
# place the data into a PCollection.
#
#
# ## Dataset / Input
#
#
# Products
#
# Laptop
# Phone
# Tablet
# Monitor
#
#
# ## Task
#
#
# Create a pipeline that prints all products.
#
#
# ## Hint
#
#
# Use:
#
# beam.Pipeline()
# beam.Create()
# beam.Map(print)

# %%
# =====================================================
# TODO
# =====================================================


# Create the pipeline

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "Laptop",
                "Phone",
                "Tablet",
                "Monitor"
            ]
        )
        | beam.Map(print)
    )
# Out:
# WARNING:apache_beam.runners.interactive.interactive_environment:Dependencies required for Interactive Beam PCollection visualization are not available, please use: `pip install apache-beam[interactive]` to install necessary dependencies to enable all data visualization features.
# Laptop
# Phone
# Tablet
# Monitor

# %% [markdown]
# # Exercise 4: Understanding PCollection
#
# ## Background
#
#
# A PCollection represents a distributed collection
# of elements in Apache Beam.
#
# Store the product names inside a PCollection.
#
#
# ## Dataset / Input
#
#
# Products
#
# Laptop
# Phone
# Tablet
# Monitor
# Keyboard
#
#
# ## Task
#
#
# Create a PCollection and print all elements.
#
#
# ## Hint
#
#
# Store data using beam.Create().

# %%
# =====================================================
# TODO
# =====================================================


# Create PCollection

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    products = (
        p
        | beam.Create(
            [
                "Laptop",
                "Phone",
                "Tablet",
                "Monitor",
                "Keyboard"
            ]
        )
    )

    products | beam.Map(print)
# Out:
# Laptop
# Phone
# Tablet
# Monitor
# Keyboard

# %% [markdown]
# # Exercise 5: Map Transformation
#
# ## Background
#
#
# Product names are stored in lowercase.
#
# Management wants all names converted to uppercase.
#
#
# ## Dataset / Input
#
#
# Products
#
# laptop
# phone
# tablet
# monitor
#
#
# ## Task
#
#
# Convert all products to uppercase.
#
#
# ## Hint
#
#
# Use beam.Map().
# Use str.upper().

# %%
# =====================================================
# TODO
# =====================================================


# Convert to uppercase

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "laptop",
                "phone",
                "tablet",
                "monitor"
            ]
        )
        | beam.Map(
            lambda x: x.upper()
        )
        | beam.Map(print)
    )
# Out:
# LAPTOP
# PHONE
# TABLET
# MONITOR

# %% [markdown]
# # Exercise 6: Filter Transformation
#
# ## Background
#
#
# The inventory team only wants products having
# more than six characters.
#
#
# ## Dataset / Input
#
#
# Products
#
# Laptop
# Phone
# Tablet
# Keyboard
# Monitor
#
#
# ## Task
#
#
# Filter products whose length is greater than 6.
#
#
# ## Hint
#
#
# Use beam.Filter().
# Use len().

# %%
# =====================================================
# TODO
# =====================================================


# Filter products

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "Laptop",
                "Phone",
                "Tablet",
                "Keyboard",
                "Monitor"
            ]
        )
        | beam.Filter(
            lambda x: len(x) > 6
        )
        | beam.Map(print)
    )
# Out:
# Keyboard
# Monitor

# %% [markdown]
# # Exercise 7: FlatMap Transformation
#
# ## Background
#
#
# Website clickstream logs are stored as sentences.
#
# Each sentence contains multiple words.
#
# FlatMap converts one element into many outputs.
#
#
# ## Dataset / Input
#
#
# Logs
#
# "user login successful"
#
# "product added cart"
#
# "checkout completed"
#
#
# ## Task
#
#
# Split every sentence into individual words.
#
#
# ## Hint
#
#
# Use:
#
# beam.FlatMap()
# str.split()

# %%
# =====================================================
# TODO
# =====================================================


# Split sentences

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "user login successful",
                "product added cart",
                "checkout completed"
            ]
        )
        | beam.FlatMap(
            lambda x: x.split()
        )
        | beam.Map(print)
    )
# Out:
# user
# login
# successful
# product
# added
# cart
# checkout
# completed

# %% [markdown]
# # Exercise 8: Product Name Length
#
# ## Background
#
#
# Management wants a report showing each product
# and the number of characters in its name.
#
#
# ## Dataset / Input
#
#
# Products
#
# Laptop
# Phone
# Tablet
#
#
# ## Task
#
#
# Create tuples:
#
# (Product, Length)
#
#
# ## Hint
#
#
# Use beam.Map().
# Return a tuple.

# %%
# =====================================================
# TODO
# =====================================================


# Create tuples

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "Laptop",
                "Phone",
                "Tablet"
            ]
        )
        | beam.Map(
            lambda x: (
                x,
                len(x)
            )
        )
        | beam.Map(print)
    )
# Out:
# ('Laptop', 6)
# ('Phone', 5)
# ('Tablet', 6)

# %% [markdown]
# # Exercise 9: GroupByKey
#
# ## Background
#
#
# An online store records daily sales.
#
# Each record is:
#
# (Product, Quantity)
#
# Multiple sales may belong to the same product.
#
#
# ## Dataset / Input
#
#
# [
#  ("Laptop",2),
#  ("Laptop",4),
#  ("Phone",1),
#  ("Phone",3)
# ]
#
#
# ## Task
#
#
# Group all quantities belonging to the same product.
#
#
# ## Hint
#
#
# Use beam.GroupByKey().

# %%
# =====================================================
# TODO
# =====================================================


# Group quantities by product

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                ("Laptop",2),
                ("Laptop",4),
                ("Phone",1),
                ("Phone",3)
            ]
        )
        | beam.GroupByKey()
        | beam.Map(print)
    )
# Out:
# ('Laptop', [2, 4])
# ('Phone', [1, 3])

# %% [markdown]
# # Exercise 10: CombinePerKey
#
# ## Background
#
#
# Management wants total sales quantity
# for each product.
#
#
# ## Dataset / Input
#
#
# [
#  ("Laptop",2),
#  ("Laptop",4),
#  ("Phone",1),
#  ("Phone",3)
# ]
#
#
# ## Task
#
#
# Compute total quantity sold for every product.
#
#
# ## Hint
#
#
# Use CombinePerKey(sum).

# %%
# =====================================================
# TODO
# =====================================================


# Compute totals

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                ("Laptop",2),
                ("Laptop",4),
                ("Phone",1),
                ("Phone",3)
            ]
        )
        | beam.CombinePerKey(sum)
        | beam.Map(print)
    )
# Out:
# ('Laptop', 6)
# ('Phone', 4)

# %% [markdown]
# # Exercise 11: Count Product Occurrences
#
# ## Background
#
#
# An inventory system records every product scan.
#
# Management wants to know how many times
# each product appears.
#
#
# ## Dataset / Input
#
#
# [
#  "Laptop",
#  "Phone",
#  "Laptop",
#  "Tablet",
#  "Phone",
#  "Laptop"
# ]
#
#
# ## Task
#
#
# Count occurrences of each product.
#
#
# ## Hint
#
#
# Use Count.PerElement().

# %%
# =====================================================
# TODO
# =====================================================


# Count occurrences

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam
from apache_beam.transforms.combiners import Count

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "Laptop",
                "Phone",
                "Laptop",
                "Tablet",
                "Phone",
                "Laptop"
            ]
        )
        | Count.PerElement()
        | beam.Map(print)
    )
# Out:
# ('Laptop', 3)
# ('Phone', 2)
# ('Tablet', 1)

# %% [markdown]
# # Exercise 12: Create Custom DoFn
#
# ## Background
#
#
# A company stores customer names
# in lowercase.
#
# Create a custom DoFn to convert names
# to uppercase.
#
#
# ## Dataset / Input
#
#
# customers =
#
# [
#  "alice",
#  "bob",
#  "charlie"
# ]
#
#
# ## Task
#
#
# Create and apply a custom DoFn.
#
#
# ## Hint
#
#
# Create a class inheriting beam.DoFn.

# %%
# =====================================================
# TODO
# =====================================================


# Create DoFn

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

class UpperCaseFn(beam.DoFn):

    def process(self, element):
        yield element.upper()

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [
                "alice",
                "bob",
                "charlie"
            ]
        )
        | beam.ParDo(
            UpperCaseFn()
        )
        | beam.Map(print)
    )
# Out:
# ALICE
# BOB
# CHARLIE

# %% [markdown]
# # Exercise 13: Create Custom CombineFn
#
# ## Background
#
#
# A store records sales values.
#
# Management wants the average sale amount.
#
# Beam allows custom aggregation through
# CombineFn.
#
#
# ## Dataset / Input
#
#
# sales =
#
# [100,200,300,400]
#
#
# ## Task
#
#
# Create a custom average CombineFn.
#
#
# ## Hint
#
#
# Implement:
#
# create_accumulator()
# add_input()
# merge_accumulators()
# extract_output()

# %%
# =====================================================
# TODO
# =====================================================


# Create custom CombineFn

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

class AverageFn(beam.CombineFn):

    def create_accumulator(self):
        return (0, 0)

    def add_input(self, acc, value):
        total, count = acc
        return (
            total + value,
            count + 1
        )

    def merge_accumulators(self, accs):

        total = sum(
            x[0]
            for x in accs
        )

        count = sum(
            x[1]
            for x in accs
        )

        return (
            total,
            count
        )

    def extract_output(self, acc):

        total, count = acc

        return total / count

with beam.Pipeline() as p:

    (
        p
        | beam.Create(
            [100,200,300,400]
        )
        | beam.CombineGlobally(
            AverageFn()
        )
        | beam.Map(print)
    )
# Out:
# 250.0

# %% [markdown]
# # Exercise 14: Pipeline DAG Understanding
#
# ## Background
#
#
# Apache Beam pipelines are represented
# internally as Directed Acyclic Graphs.
#
# Consider the following workflow.
#
# Read Orders
#     ↓
# Map
#     ↓
# Filter
#     ↓
# Write Output
#
#
# ## Dataset / Input
#
#
# Pipeline Diagram Above
#
#
# ## Task
#
#
# Draw the DAG and explain why Beam
# uses DAG execution.
#
#
# ## Hint
#
#
# Think about parallel execution.

# %%
# =====================================================
# TODO
# =====================================================


# Write your explanation

# %% [markdown]
# ## Solution

# %%
print(
'''
Beam uses DAG execution because:

1. Dependencies are explicit.
2. Stages can execute in parallel.
3. Cycles are avoided.
4. Optimization becomes easier.
'''
)
# Out:
# Beam uses DAG execution because:
#
# 1. Dependencies are explicit.
# 2. Stages can execute in parallel.
# 3. Cycles are avoided.
# 4. Optimization becomes easier.

# %% [markdown]
# # Exercise 15: Bounded Dataset
#
# ## Background
#
#
# Bounded datasets have a finite number
# of elements.
#
# Example:
# Historical sales data.
#
#
# ## Dataset / Input
#
#
# sales.csv
#
# contains 10000 records
#
#
# ## Task
#
#
# Explain why this dataset is bounded.
#
#
# ## Hint
#
#
# Think about whether new records
# continue arriving.

# %%
# =====================================================
# TODO
# =====================================================


# Write explanation

# %% [markdown]
# ## Solution

# %%
print(
'''
The dataset is bounded because
it has a fixed number of records
and does not continuously grow.
'''
)
# Out:
# The dataset is bounded because
# it has a fixed number of records
# and does not continuously grow.

# %% [markdown]
# # Exercise 16: Unbounded Dataset
#
# ## Background
#
#
# Website click events arrive continuously.
#
# Such streams have no predefined end.
#
#
# ## Dataset / Input
#
#
# Real-time click stream
#
#
# ## Task
#
#
# Explain why this dataset is unbounded.
#
#
# ## Hint
#
#
# Think about streaming systems.

# %%
# =====================================================
# TODO
# =====================================================


# Write explanation

# %% [markdown]
# ## Solution

# %%
print(
'''
The stream is unbounded because
new events continue arriving
indefinitely.
'''
)
# Out:
# The stream is unbounded because
# new events continue arriving
# indefinitely.

# %% [markdown]
# # Exercise 17: Fixed Window Sales Aggregation
#
# ## Background
#
#
# An online store receives sales events every minute.
#
# Streaming systems cannot aggregate an infinite
# stream forever.
#
# Apache Beam solves this using windows.
#
# For simplicity, we will manually assign events
# to fixed windows.
#
# Window_1 = 09:00 - 09:04
#
# Window_2 = 09:05 - 09:09
#
#
# ## Dataset / Input
#
#
# sales =
#
# [
#     ("09:00",100),
#     ("09:01",200),
#     ("09:03",150),
#     ("09:05",300),
#     ("09:06",250),
#     ("09:09",100)
# ]
#
#
# ## Task
#
#
# Assign each event to the correct window and
# compute total sales per window.
#
# Expected Output
#
# ('Window_1',450)
#
# ('Window_2',650)
#
#
# ## Hint
#
#
# 1. Create tuples of the form:
#
# (window_name,sales)
#
# 2. Use CombinePerKey(sum)
#
# 3. Print the results.

# %%
# =====================================================
# TODO
# =====================================================


# Assign windows and compute totals

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

windowed_sales = [

    ("Window_1",100),
    ("Window_1",200),
    ("Window_1",150),

    ("Window_2",300),
    ("Window_2",250),
    ("Window_2",100)

]

with beam.Pipeline() as p:

    (
        p
        | beam.Create(windowed_sales)
        | beam.CombinePerKey(sum)
        | beam.Map(print)
    )
# Out:
# ('Window_1', 450)
# ('Window_2', 650)

# %% [markdown]
# # Exercise 18: Detect Late Events using Watermark Logic
#
# ## Background
#
#
# In streaming systems some events arrive late.
#
# A watermark estimates how complete the
# event-time stream is.
#
# Assume the current watermark is 100.
#
# Any event with timestamp less than 100
# should be considered late.
#
#
# ## Dataset / Input
#
#
# events =
#
# [
#     ("user1",95),
#     ("user2",102),
#     ("user3",98),
#     ("user4",110),
#     ("user5",105)
# ]
#
# watermark = 100
#
#
# ## Task
#
#
# Identify all late events.
#
# Expected Output
#
# ('user1',95)
#
# ('user3',98)
#
#
# ## Hint
#
#
# Use beam.Filter().
#
# Keep only records having timestamp
# less than watermark.

# %%
# =====================================================
# TODO
# =====================================================


# Filter late events

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

watermark = 100

events = [

    ("user1",95),
    ("user2",102),
    ("user3",98),
    ("user4",110),
    ("user5",105)

]

with beam.Pipeline() as p:

    (
        p
        | beam.Create(events)
        | beam.Filter(
            lambda x: x[1] < watermark
        )
        | beam.Map(print)
    )
# Out:
# ('user1', 95)
# ('user3', 98)

# %% [markdown]
# # Exercise 19: Trigger Simulation using Running Sales
#
# ## Background
#
#
# Triggers determine when Beam should emit
# results before a window fully completes.
#
# Suppose management wants an early report
# whenever cumulative sales exceed 500.
#
# We will simulate this behavior using Python.
#
#
# ## Dataset / Input
#
#
# sales =
#
# [
#     100,
#     200,
#     250,
#     300,
#     150
# ]
#
#
# ## Task
#
#
# Generate a trigger whenever the cumulative
# sales cross 500.
#
# Expected Output
#
# Trigger Fired: 550
#
# Trigger Fired: 850
#
# Trigger Fired: 1000
#
#
# ## Hint
#
#
# Maintain a running total.
#
# Check whether the total exceeds 500.

# %%
# =====================================================
# TODO
# =====================================================


# Trigger simulation

# %% [markdown]
# ## Solution

# %%
sales = [

    100,
    200,
    250,
    300,
    150

]

running_total = 0

for sale in sales:

    running_total += sale

    if running_total >= 500:

        print(
            "Trigger Fired:",
            running_total
        )
# Out:
# Trigger Fired: 550
# Trigger Fired: 850
# Trigger Fired: 1000

# %% [markdown]
# # Exercise 20: State and Timer Simulation
#
# ## Background
#
#
# Many real-time systems need to remember
# information across events.
#
# Beam provides State and Timers.
#
# In this exercise:
#
# State:
#     Number of visits per customer
#
# Timer:
#     Emit an alert when a customer reaches
#     3 visits
#
#
# ## Dataset / Input
#
#
# visits =
#
# [
#     "Alice",
#     "Bob",
#     "Alice",
#     "Alice",
#     "Bob",
#     "Charlie",
#     "Bob",
#     "Bob"
# ]
#
#
# ## Task
#
#
# Count customer visits.
#
# Generate an alert whenever a customer
# reaches exactly 3 visits.
#
# Expected Output
#
# Timer Alert: Alice reached 3 visits
#
# Timer Alert: Bob reached 3 visits
#
#
# ## Hint
#
#
# Use a dictionary to simulate State.
#
# Increment visit counts.
#
# Check when count == 3.

# %%
# =====================================================
# TODO
# =====================================================


# State and Timer simulation

# %% [markdown]
# ## Solution

# %%
state = {}

visits = [

    "Alice",
    "Bob",
    "Alice",
    "Alice",
    "Bob",
    "Charlie",
    "Bob",
    "Bob"

]

for customer in visits:

    state[customer] = (
        state.get(customer,0)
        + 1
    )

    if state[customer] == 3:

        print(
            f"Timer Alert: "
            f"{customer} reached "
            f"3 visits"
        )

print()

print("Final State")

print(state)
# Out:
# Timer Alert: Alice reached 3 visits
# Timer Alert: Bob reached 3 visits
#
# Final State
# {'Alice': 3, 'Bob': 4, 'Charlie': 1}

# %% [markdown]
# # Exercise 21: Mini Project: E-Commerce Order Analytics
#
# ## Background
#
#
# You are working as a Data Engineer for an
# e-commerce company.
#
# The company records orders in the format:
#
# (Product, Quantity)
#
# Management wants a report showing total
# sales quantity for each product.
#
#
# ## Dataset / Input
#
#
# orders =
#
# [
#     ("Laptop",2),
#     ("Phone",1),
#     ("Laptop",3),
#     ("Tablet",4),
#     ("Phone",2),
#     ("Tablet",1),
#     ("Laptop",1)
# ]
#
#
# ## Task
#
#
# Build a Beam pipeline that:
#
# 1. Creates a PCollection.
# 2. Aggregates quantities per product.
# 3. Displays total quantity sold.
#
# Expected Output
#
# ('Laptop',6)
#
# ('Phone',3)
#
# ('Tablet',5)
#
#
# ## Hint
#
#
# Use:
#
# beam.Create()
#
# CombinePerKey(sum)

# %%
# =====================================================
# TODO
# =====================================================


# Complete the pipeline

# %% [markdown]
# ## Solution

# %%
import apache_beam as beam

orders = [

    ("Laptop",2),
    ("Phone",1),
    ("Laptop",3),
    ("Tablet",4),
    ("Phone",2),
    ("Tablet",1),
    ("Laptop",1)

]

with beam.Pipeline() as p:

    (
        p
        | beam.Create(orders)
        | beam.CombinePerKey(sum)
        | beam.Map(print)
    )
# Out:
# ('Laptop', 6)
# ('Phone', 3)
# ('Tablet', 5)

# %% [markdown]
# # Spark ML
#
# In the next section we will build a complete
# Customer Churn Prediction Pipeline using:
#
# - DataFrames
# - Transformers
# - Estimators
# - Pipelines
# - Cross Validation
# - Model Persistence
#
# A single telecom churn dataset will be reused
# throughout all exercises.

# %% [markdown]
# # Apache Beam Review
#
# You have now covered:
#
# - Pipeline
# - PCollection
# - PTransform
# - Map
# - Filter
# - FlatMap
# - GroupByKey
# - CombinePerKey
# - Count
# - DoFn
# - CombineFn
# - Windowing
# - Watermarks
# - Triggers
# - State
# - Timers
#
# Next we begin Spark ML using a telecom
# customer churn prediction dataset that
# will be reused throughout the remainder
# of the notebook.

# %% [markdown]
# # Spark ML
#
# In this section we will build a complete
# Customer Churn Prediction Pipeline.
#
# Business Problem:
#
# A telecom company wants to predict whether
# a customer will leave the service.
#
# Target Column:
#
# churn
#
# 0 → Customer Stays
#
# 1 → Customer Leaves
#
# The same dataset will be reused throughout
# all Spark ML exercises.

# %% [markdown]
# # Exercise 21: Create Spark Session
#
# ## Background
#
#
# Every Spark application begins by creating
# a SparkSession.
#
# The SparkSession is the entry point for
# DataFrame operations and Spark ML.
#
#
# ## Dataset / Input
#
#
# No dataset required.
#
#
# ## Task
#
#
# Create a SparkSession named ChurnPrediction.
#
#
# ## Hint
#
#
# Use SparkSession.builder.

# %%
# =====================================================
# TODO
# =====================================================


# Create SparkSession

# %% [markdown]
# ## Solution

# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("ChurnPrediction")
    .getOrCreate()
)

print(spark.version)
# Out:
# 4.0.2

# %% [markdown]
# # Exercise 22: Create Telecom Churn Dataset
#
# ## Background
#
#
# A telecom company has collected information
# about its customers.
#
# This dataset will be reused throughout
# the Spark ML exercises.
#
#
# ## Dataset / Input
#
#
# Columns
#
# age
# monthly_bill
# support_calls
# contract_type
# churn
#
# Sample Rows
#
# 25,300,1,Prepaid,0
# 45,900,5,Postpaid,1
# 35,450,2,Prepaid,0
# 55,1200,6,Postpaid,1
#
#
# ## Task
#
#
# Create a Spark DataFrame containing
# the telecom dataset.
#
#
# ## Hint
#
#
# Use spark.createDataFrame().

# %%
# =====================================================
# TODO
# =====================================================


# Create DataFrame

# %% [markdown]
# ## Solution

# %%
data = [

    (25,300,1,"Prepaid",0),
    (45,900,5,"Postpaid",1),
    (35,450,2,"Prepaid",0),
    (55,1200,6,"Postpaid",1),
    (30,350,2,"Prepaid",0),
    (50,1000,7,"Postpaid",1),
    (28,400,1,"Prepaid",0),
    (60,1300,8,"Postpaid",1)

]

columns = [
    "age",
    "monthly_bill",
    "support_calls",
    "contract_type",
    "churn"
]

df = spark.createDataFrame(
    data,
    columns
)

df.show()
# Out:
# +---+------------+-------------+-------------+-----+
# |age|monthly_bill|support_calls|contract_type|churn|
# +---+------------+-------------+-------------+-----+
# | 25|         300|            1|      Prepaid|    0|
# | 45|         900|            5|     Postpaid|    1|
# | 35|         450|            2|      Prepaid|    0|
# | 55|        1200|            6|     Postpaid|    1|
# | 30|         350|            2|      Prepaid|    0|
# | 50|        1000|            7|     Postpaid|    1|
# | 28|         400|            1|      Prepaid|    0|
# | 60|        1300|            8|     Postpaid|    1|
# +---+------------+-------------+-------------+-----+

# %% [markdown]
# # Exercise 23: Inspect Schema
#
# ## Background
#
#
# Understanding the schema is the first
# step before building ML pipelines.
#
#
# ## Dataset / Input
#
#
# Telecom DataFrame
#
#
# ## Task
#
#
# Display the schema of the dataset.
#
#
# ## Hint
#
#
# Use printSchema().

# %%
# =====================================================
# TODO
# =====================================================


# Display schema

# %% [markdown]
# ## Solution

# %%
df.printSchema()
# Out:
# root
#  |-- age: long (nullable = true)
#  |-- monthly_bill: long (nullable = true)
#  |-- support_calls: long (nullable = true)
#  |-- contract_type: string (nullable = true)
#  |-- churn: long (nullable = true)

# %% [markdown]
# # Exercise 24: Basic Data Exploration
#
# ## Background
#
#
# Before training a model we should understand
# the available data.
#
#
# ## Dataset / Input
#
#
# Telecom Dataset
#
#
# ## Task
#
#
# Display:
#
# 1. Number of rows
# 2. Number of columns
# 3. First five records
#
#
# ## Hint
#
#
# Use count(), columns and show().

# %%
# =====================================================
# TODO
# =====================================================


# Explore data

# %% [markdown]
# ## Solution

# %%
print("Rows:", df.count())

print("Columns:", len(df.columns))

df.show(5)
# Out:
# Rows: 8
# Columns: 5
# +---+------------+-------------+-------------+-----+
# |age|monthly_bill|support_calls|contract_type|churn|
# +---+------------+-------------+-------------+-----+
# | 25|         300|            1|      Prepaid|    0|
# | 45|         900|            5|     Postpaid|    1|
# | 35|         450|            2|      Prepaid|    0|
# | 55|        1200|            6|     Postpaid|    1|
# | 30|         350|            2|      Prepaid|    0|
# +---+------------+-------------+-------------+-----+
# only showing top 5 rows

# %% [markdown]
# # Exercise 25: Describe Dataset
#
# ## Background
#
#
# Statistical summaries provide useful
# insights before model training.
#
#
# ## Dataset / Input
#
#
# Telecom Dataset
#
#
# ## Task
#
#
# Generate summary statistics.
#
#
# ## Hint
#
#
# Use describe().

# %%
# =====================================================
# TODO
# =====================================================


# Generate summary

# %% [markdown]
# ## Solution

# %%
df.describe().show()
# Out:
# +-------+------------------+-----------------+------------------+-------------+------------------+
# |summary|               age|     monthly_bill|     support_calls|contract_type|             churn|
# +-------+------------------+-----------------+------------------+-------------+------------------+
# |  count|                 8|                8|                 8|            8|                 8|
# |   mean|              41.0|            737.5|               4.0|         NULL|               0.5|
# | stddev|13.288018233409698|407.7376607575023|2.8284271247461903|         NULL|0.5345224838248488|
# |    min|                25|              300|                 1|     Postpaid|                 0|
# |    max|                60|             1300|                 8|      Prepaid|                 1|
# +-------+------------------+-----------------+------------------+-------------+------------------+

# %% [markdown]
# # Exercise 26: StringIndexer
#
# ## Background
#
#
# Machine learning algorithms cannot directly
# process string categories.
#
# StringIndexer converts categories into
# numeric labels.
#
#
# ## Dataset / Input
#
#
# contract_type
#
# Prepaid
# Postpaid
#
#
# ## Task
#
#
# Convert contract_type into a numeric column.
#
#
# ## Hint
#
#
# Use StringIndexer.

# %%
# =====================================================
# TODO
# =====================================================


# Apply StringIndexer

# %% [markdown]
# ## Solution

# %%
from pyspark.ml.feature import StringIndexer

indexer = StringIndexer(
    inputCol="contract_type",
    outputCol="contract_index"
)

indexed_df = indexer.fit(df).transform(df)

indexed_df.show()
# Out:
# +---+------------+-------------+-------------+-----+--------------+
# |age|monthly_bill|support_calls|contract_type|churn|contract_index|
# +---+------------+-------------+-------------+-----+--------------+
# | 25|         300|            1|      Prepaid|    0|           1.0|
# | 45|         900|            5|     Postpaid|    1|           0.0|
# | 35|         450|            2|      Prepaid|    0|           1.0|
# | 55|        1200|            6|     Postpaid|    1|           0.0|
# | 30|         350|            2|      Prepaid|    0|           1.0|
# | 50|        1000|            7|     Postpaid|    1|           0.0|
# | 28|         400|            1|      Prepaid|    0|           1.0|
# | 60|        1300|            8|     Postpaid|    1|           0.0|
# +---+------------+-------------+-------------+-----+--------------+

# %% [markdown]
# # Exercise 27: OneHotEncoder
#
# ## Background
#
#
# Some algorithms benefit from one-hot encoded
# categorical features.
#
#
# ## Dataset / Input
#
#
# contract_index
#
#
# ## Task
#
#
# Create one-hot encoded vectors.
#
#
# ## Hint
#
#
# Use OneHotEncoder.

# %%
# =====================================================
# TODO
# =====================================================


# One hot encode

# %% [markdown]
# ## Solution

# %%
from pyspark.ml.feature import OneHotEncoder

encoder = OneHotEncoder(
    inputCols=["contract_index"],
    outputCols=["contract_vector"]
)

encoded_df = encoder.fit(
    indexed_df
).transform(
    indexed_df
)

encoded_df.show()
# Out:
# +---+------------+-------------+-------------+-----+--------------+---------------+
# |age|monthly_bill|support_calls|contract_type|churn|contract_index|contract_vector|
# +---+------------+-------------+-------------+-----+--------------+---------------+
# | 25|         300|            1|      Prepaid|    0|           1.0|      (1,[],[])|
# | 45|         900|            5|     Postpaid|    1|           0.0|  (1,[0],[1.0])|
# | 35|         450|            2|      Prepaid|    0|           1.0|      (1,[],[])|
# | 55|        1200|            6|     Postpaid|    1|           0.0|  (1,[0],[1.0])|
# | 30|         350|            2|      Prepaid|    0|           1.0|      (1,[],[])|
# | 50|        1000|            7|     Postpaid|    1|           0.0|  (1,[0],[1.0])|
# | 28|         400|            1|      Prepaid|    0|           1.0|      (1,[],[])|
# | 60|        1300|            8|     Postpaid|    1|           0.0|  (1,[0],[1.0])|
# ...

# %% [markdown]
# # Exercise 28: VectorAssembler
#
# ## Background
#
#
# Spark ML algorithms expect a single
# feature vector column.
#
#
# ## Dataset / Input
#
#
# Features
#
# age
# monthly_bill
# support_calls
# contract_index
#
#
# ## Task
#
#
# Create a features vector.
#
#
# ## Hint
#
#
# Use VectorAssembler.

# %%
# =====================================================
# TODO
# =====================================================


# Create feature vector

# %% [markdown]
# ## Solution

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(

    inputCols=[
        "age",
        "monthly_bill",
        "support_calls",
        "contract_index"
    ],

    outputCol="features"
)

feature_df = assembler.transform(
    indexed_df
)

feature_df.select(
    "features",
    "churn"
).show(
    truncate=False
)
# Out:
# +---------------------+-----+
# |features             |churn|
# +---------------------+-----+
# |[25.0,300.0,1.0,1.0] |0    |
# |[45.0,900.0,5.0,0.0] |1    |
# |[35.0,450.0,2.0,1.0] |0    |
# |[55.0,1200.0,6.0,0.0]|1    |
# |[30.0,350.0,2.0,1.0] |0    |
# |[50.0,1000.0,7.0,0.0]|1    |
# |[28.0,400.0,1.0,1.0] |0    |
# |[60.0,1300.0,8.0,0.0]|1    |
# +---------------------+-----+

# %% [markdown]
# # Exercise 29: Train Test Split
#
# ## Background
#
#
# Models should be evaluated on unseen data.
#
#
# ## Dataset / Input
#
#
# feature_df
#
#
# ## Task
#
#
# Split the dataset into training
# and testing sets.
#
#
# ## Hint
#
#
# Use randomSplit().

# %%
# =====================================================
# TODO
# =====================================================


# Split dataset

# %% [markdown]
# ## Solution

# %%
train_df, test_df = (

    feature_df.randomSplit(
        [0.8,0.2],
        seed=42
    )

)

print(train_df.count())
print(test_df.count())
# Out:
# 6
# 2

# %% [markdown]
# # Exercise 30: Logistic Regression
#
# ## Background
#
#
# Logistic Regression is a popular
# classification algorithm.
#
#
# ## Dataset / Input
#
#
# Training Dataset
#
#
# ## Task
#
#
# Train a Logistic Regression model.
#
#
# ## Hint
#
#
# Use LogisticRegression.

# %%
# =====================================================
# TODO
# =====================================================


# Train model

# %% [markdown]
# ## Solution

# %%
from pyspark.ml.classification import (
    LogisticRegression
)

lr = LogisticRegression(

    featuresCol="features",
    labelCol="churn"

)

model = lr.fit(train_df)

predictions = model.transform(
    test_df
)

predictions.select(
    "churn",
    "prediction"
).show()
# Out:
# +-----+----------+
# |churn|prediction|
# +-----+----------+
# |    1|       1.0|
# |    0|       0.0|
# +-----+----------+
